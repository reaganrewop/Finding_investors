# %%
import pandas as pd
import numpy as np
from pymongo import MongoClient
import pprint
import json
from bson import json_util

# %%
client = MongoClient("mongodb+srv://root:toor@cluster0-zifmo.mongodb.net/show")

# %%
db = client['show']

# %%
collection = db['show']

# %%
serverStatusResult=db.command("serverStatus")
#display(serverStatusResult)

# %%
with open("season7.json",'r') as f:
    data = json.load(f)
# Out:
# {'Episode 1': [{'company': {'link': 'http://www.thebeebo.com/',
#     'title': 'The Beebo'},
#    'investors': 'Lori Greiner and Ashton Kutcher',
#    'kitna': '$200K for 30%',
#    'location': 'Wellington, FL',
#    'product': '\nBottle Feeding Shoulder Strap\n',
#    'social': ['https://www.facebook.com/TheBeebo',
#     'https://twitter.com/the_beebo',
#     'https://instagram.com/the_beebo/',
#     'https://www.youtube.com/watch?v=OH8b6DQTFS4'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.mcclarybros.com/',
#     'title': 'McClary Brothers Drinking Vinegars'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Detroit, MI',
#    'product': 'Drinking Vinegar',
#    'social': ['https://www.facebook.com/mcclarybros',
#     'https://twitter.com/mcclarybros',
#     'https://instagram.com/mcclarybros/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://www.signal-vault.com/',
#     'title': 'Signal Vault'},
#    'investors': 'Robert Herjavec and Lori Greiner',
#    'kitna': '\xa0$200K for 25',
#    'location': 'Orlando, FL',
#    'product': 'Credit Card Protector',
#    'social': ['https://www.facebook.com/SignalVault/timeline/',
#     'https://twitter.com/signalvault',
#     'https://instagram.com/signalvault/',
#     'https://www.youtube.com/channel/UCb'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.actonglobal.com/',
#     'title': 'Acton Rocket Skates'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Los Angeles, CA',
#    'product': 'Modern Skates',
#    'social': ['https://www.facebook.com/ACTONglobal',
#     'http://inwiththesharks.com/seasons/season-7/www.twitter.com/gorocketskates',
#     'https://instagram.com/gorocketskates',
#     'https://www.youtube.com/user/actonrocketskates'],
#    'status': 'Not Funded'}],
#  'Episode 10': [{'company': {'link': 'http://www.leauxracingtrikes.com/',
#     'title': 'Leaux Racing Trikes'},
#    'investors': '',
#    'kitna': '',
#    'location': 'San Diego, CA',
#    'product': 'Custom Trikes',
#    'social': ['https://www.facebook.com/Leaux-Racing-Trikes-574947289184195/',
#     'https://www.instagram.com/leaux_racing_trikes/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://www.glowrecipe.com/', 'title': 'Glow Recipe'},
#    'investors': 'Robert Herjavec',
#    'kitna': '$425K for 25%',
#    'location': 'New York, NY',
#    'product': 'Natural Korean Beauty',
#    'social': ['https://www.facebook.com/glowrecipe',
#     'https://twitter.com/glowrecipe',
#     'https://www.instagram.com/glowrecipe/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://saraholiverhandbags.com/',
#     'title': 'Sarah Oliver Handbags'},
#    'investors': 'Lori Greiner, Robert Herjavec, and Kevin O’Leary',
#    'kitna': '$250K for 30%',
#    'location': 'Mill Valley, CA',
#    'product': 'Hand Knit Bags',
#    'social': ['https://www.facebook.com/saraholiverbags',
#     'https://twitter.com/saraholiverbags',
#     'https://www.instagram.com/saraholiverhandbags/'],
#    'status': 'Funded'},
#   {'company': {'link': 'https://www.trunkster.co/', 'title': 'Trunkster'},
#    'investors': 'Lori Greiner and Mark Cuban',
#    'kitna': '$1.4M for 5%',
#    'location': 'New York, NY',
#    'product': 'Unconventional Luggage',
#    'social': ['https://www.facebook.com/trunkstercase',
#     'https://twitter.com/trunkstercase',
#     'https://www.instagram.com/trunkstercase/'],
#    'status': 'Funded'}],
#  'Episode 11': [{'company': {'link': 'https://www.lovepopcards.com/',
#     'title': 'Lovepop'},
#    'investors': 'Kevin O’Leary',
#    'kitna': '$300K for 15%',
#    'location': 'Cambridge, MA',
#    'product': 'Greeting Cards',
#    'social': ['https://www.facebook.com/lovepopcards',
#     'https://twitter.com/lovepop',
#     'https://www.instagram.com/lovepopcards/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.geekmytree.com/', 'title': 'GeekMyTree'},
#    'investors': 'Kevin O’Leary',
#    'kitna': '$225K for 50%',
#    'location': 'Green Haven, MI',
#    'product': 'Animated Holiday Lighting',
#    'social': ['https://www.facebook.com/geekmytree?_rdr=p',
#     'https://twitter.com/geekmytree',
#     'https://www.instagram.com/geekmytree/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.beardhead.com/', 'title': 'BeardHead'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Los Angeles, CA',
#    'product': 'Bearded Beanies',
#    'social': ['https://www.facebook.com/beardheads',
#     'https://twitter.com/beardhead',
#     'https://www.instagram.com/beardhead/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://piperwai.com/', 'title': 'PiperWai'},
#    'investors': 'Barbara Corcoran',
#    'kitna': '$50K for 25%',
#    'location': 'Philadelphia, PA',
#    'product': 'Natural Deoderant',
#    'social': ['https://www.facebook.com/piperwai',
#     'https://twitter.com/piperwai',
#     'https://www.instagram.com/piperwai/'],
#    'status': 'Funded'}],
#  'Episode 12': [{'company': {'link': 'https://www.extremesandbox.com/',
#     'title': 'Extreme Sandbox\xa0'},
#    'investors': 'Mark Cuban and Kevin O’ Leary',
#    'kitna': '$150K for 20%',
#    'location': 'Hastings, MN',
#    'product': 'Construction Playground',
#    'social': ['https://www.facebook.com/ExtremeSandbox',
#     'https://twitter.com/ExtremeSandbox',
#     'https://www.instagram.com/extremesandbox/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.fireavert.com/', 'title': 'Fire Avert'},
#    'investors': 'Lori Greiner',
#    'kitna': '$300K for 10%',
#    'location': 'Provo, UT',
#    'product': 'Auto Stove Shutoff',
#    'social': ['https://www.facebook.com/FireAvert',
#     'https://twitter.com/fireavert',
#     'https://www.instagram.com/fire_avert/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://abspancakes.com/',
#     'title': 'ABS Protein Pancakes'},
#    'investors': 'Daymond John',
#    'kitna': '$120K for 42%',
#    'location': 'Tampa, FL',
#    'product': 'Protein Pancakes',
#    'social': ['https://www.facebook.com/absproteinpancakes?_rdr=p',
#     'https://twitter.com/AshleyDrummonds',
#     'https://www.instagram.com/abs_proteinpancakes/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.totaltiekeep.com/',
#     'title': 'Total Tie Keep'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Alexandria, VA',
#    'product': 'Neck Ties',
#    'social': ['https://www.facebook.com/Total-Tie-Keep-1214032748611413/',
#     'https://twitter.com/totaltiekeep',
#     'https://www.instagram.com/totaltiekeep/'],
#    'status': 'Not Funded'}],
#  'Episode 13': [{'company': {'link': 'http://www.hungryharvest.net/',
#     'title': 'Hungry Harvest'},
#    'investors': 'Robert Herjavec',
#    'kitna': '$100K for 10%',
#    'location': 'Baltimore, MD',
#    'product': 'Produce Delivery',
#    'social': ['https://www.facebook.com/HungryHarvest/',
#     'https://twitter.com/HungryHarvest',
#     'https://www.instagram.com/hungryharvest/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://controlledchaoshair.com/',
#     'title': 'Controlled Chaos'},
#    'investors': 'Lori Greiner',
#    'kitna': '$60K for 50%',
#    'location': 'Portland, ME',
#    'product': 'Beauty Products',
#    'social': ['https://www.facebook.com/ControlledChaosHair/',
#     'https://twitter.com/CChaosHair',
#     'https://www.instagram.com/controlledchaoshair/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.spretzme.com/', 'title': 'Spretz Me!'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Oakland, CA',
#    'product': 'Breath and Hand Freshener',
#    'social': ['https://www.facebook.com/Spretzme/',
#     'https://twitter.com/spretzme',
#     'https://www.instagram.com/spretzme/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://www.ezpzfun.com/', 'title': 'Espz'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Parker, CO',
#    'product': 'Children Plates',
#    'social': ['https://www.facebook.com/ezpzfun',
#     'https://twitter.com/ezpzfun',
#     'https://www.instagram.com/ezpzfun/'],
#    'status': 'Not Funded'}],
#  'Episode 14': [{'company': {'link': 'https://www.fixed.com/',
#     'title': 'Fixed'},
#    'investors': 'Mark Cuban',
#    'kitna': '$700K for 7%',
#    'location': 'San Francisco, CA',
#    'product': 'Ticket Dismissals',
#    'social': ['https://www.facebook.com/getfixed.me/',
#     'https://twitter.com/fixed',
#     'https://www.instagram.com/fixed.sf/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.hatchbaby.com/', 'title': 'Hatch Baby'},
#    'investors': 'Chris Sacca',
#    'kitna': '$250K for 2.5%',
#    'location': 'Menlo, CA',
#    'product': 'Smart Changing Pad',
#    'social': ['https://www.facebook.com/hatchnursery',
#     'https://twitter.com/hatchbaby',
#     'https://www.instagram.com/hatchnursery/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://thebeardking.com/', 'title': 'Beard King'},
#    'investors': 'Lori Greiner',
#    'kitna': '$100K for 45%',
#    'location': 'Pompano Beach, FL',
#    'product': 'Beard Products',
#    'social': ['https://www.facebook.com/beardking',
#     'https://twitter.com/beardking',
#     'https://www.instagram.com/beardking/'],
#    'status': 'Funded'},
#   {'company': {'link': 'https://www.villagescholarships.com/',
#     'title': 'Village Scholarships'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Denver, CO',
#    'product': 'Automated Scholarships Service',
#    'social': ['https://www.facebook.com/VillageScholarships/',
#     'https://twitter.com/VScholarships?lang=en'],
#    'status': 'Not Funded'}],
#  'Episode 15': [{'company': {'link': 'http://www.co-alition.com/',
#     'title': 'CO.Alition'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Denver, CO',
#    'product': 'Revolutionary Backpack',
#    'social': ['https://www.facebook.com/coalitiongear/',
#     'https://twitter.com/co_alition',
#     'https://www.instagram.com/co.alition/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://shefit.com/', 'title': 'SheFit'},
#    'investors': 'Daymond John',
#    'kitna': '$250K for 33%',
#    'location': 'Jenison, MI',
#    'product': 'Sports Bra',
#    'social': ['https://www.facebook.com/shefitapparel',
#     'https://twitter.com/Shefit',
#     'https://www.instagram.com/shefitapparel/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.icybreeze.com/', 'title': 'IcyBreeze'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Bixby, OK',
#    'product': 'Portable AC Cooler',
#    'social': ['https://www.facebook.com/GetanIcyBreeze',
#     'https://twitter.com/GetIcyBreeze',
#     'https://www.instagram.com/geticybreeze/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'https://2400expert.com/', 'title': '2400 Expert'},
#    'investors': 'Mark Cuban',
#    'kitna': '$250K for 20%',
#    'location': 'Las Vegas, NV',
#    'product': 'SAT/ACT Prep Courses',
#    'social': ['https://www.facebook.com/2400Expert/',
#     'https://twitter.com/2400expert',
#     'https://www.instagram.com/2400_expert/'],
#    'status': 'Funded'}],
#  'Episode 16': [{'company': {'link': 'http://www.rriveter.com/',
#     'title': 'R Riveter'},
#    'investors': 'Mark Cuban',
#    'kitna': '$100K for 20%',
#    'location': 'Southern Pines, NC',
#    'product': 'Handmade American Handbags',
#    'social': ['https://www.facebook.com/RRiveterBags',
#     'https://twitter.com/rriveterbags',
#     'https://www.instagram.com/rriveterbags/'],
#    'status': 'Funded'},
#   {'company': {'link': 'https://www.beartekgloves.com/', 'title': 'BearTek'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Dallas, TX',
#    'product': 'SmartGloves',
#    'social': ['https://www.facebook.com/BearTekGloves',
#     'https://twitter.com/BearTekGloves',
#     'https://www.instagram.com/beartekgloves/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://www.combatflipflops.com/',
#     'title': 'Combat Flip Flops'},
#    'investors': 'Daymond John, Mark Cuban, Lori Greiner',
#    'kitna': '$300K for 30%',
#    'location': 'Issaquah, WA',
#    'product': 'Flip Flops',
#    'social': ['https://www.facebook.com/combatflipflops',
#     'https://twitter.com/combatflipflops',
#     'https://instagram.com/combatflipflops/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.majormom.biz/', 'title': 'Major Mom'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Greenwood Village, CO',
#    'product': 'Professional Organization',
#    'social': ['https://www.facebook.com/TheMajorMom',
#     'https://twitter.com/TheMajorMom'],
#    'status': 'Not Funded'}],
#  'Episode 17': [{'company': {'link': 'http://www.floatbabies.com/',
#     'title': 'Float Baby'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Houston, TX',
#    'product': 'Water Therapy',
#    'social': ['https://www.facebook.com/FloatBaby/',
#     'https://twitter.com/FloatBaby',
#     'http://instagram.com/floatbaby'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'https://www.mtailor.com/', 'title': 'Mtailor'},
#    'investors': '',
#    'kitna': '',
#    'location': 'San Francisco, CA',
#    'product': 'Custom Tailor App',
#    'social': ['https://www.facebook.com/theMTailor/',
#     'https://twitter.com/mtailor',
#     'https://www.instagram.com/themtailor/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://www.beefreehonee.com/',
#     'title': 'Bee Free Honee'},
#    'investors': 'Barbara Corcoran, Mark Cuban, and Chris Sacca',
#    'kitna': '$210K for 30%',
#    'location': 'Minneapolis, MN',
#    'product': 'Plant-based Honey',
#    'social': ['https://www.facebook.com/beefreehonee',
#     'https://twitter.com/beefreehonee',
#     'https://www.instagram.com/beefreehonee/'],
#    'status': 'Funded'},
#   {'company': {'link': 'https://getsmartplate.com/', 'title': 'SmartPlate'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Philadelphia, PA',
#    'product': 'Intelligent Food Plate',
#    'social': ['https://www.facebook.com/GetSmartPlate',
#     'https://twitter.com/getsmartplate',
#     'http://instagram.com/getsmartplate'],
#    'status': 'Not Funded'}],
#  'Episode 18': [{'company': {'link': 'https://nohboball.com/',
#     'title': 'Nohbo'},
#    'investors': 'Mark Cuban',
#    'kitna': '$100K for 25%',
#    'location': 'Melbourne, FL',
#    'product': 'Shampoo Ball',
#    'social': ['https://www.facebook.com/Nohboball/',
#     'https://twitter.com/nohboball',
#     'https://www.instagram.com/nohboball/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.tutublue.com/', 'title': 'TutuBlue'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Sherman Oaks, CA',
#    'product': 'Protective Activewear',
#    'social': ['https://www.facebook.com/Tutublue-879268355462176',
#     'https://twitter.com/TutublueCA',
#     'https://www.instagram.com/tutublueca/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://cleansleep.com/', 'title': 'Clean Sleep'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Flower Mound, TX',
#    'product': 'Mattress Cleaning',
#    'social': ['https://www.facebook.com/CleanSleepCo/',
#     'https://twitter.com/CleanSleepCo',
#     'https://www.instagram.com/cleansleepco/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://sworkit.com/', 'title': 'Swork It'},
#    'investors': 'Mark Cuban',
#    'kitna': '$1.5M for 10%',
#    'location': 'Washington, DC',
#    'product': 'Personalized Video Workouts',
#    'social': ['https://www.facebook.com/SworkitApps',
#     'https://twitter.com/sworkit',
#     'https://www.instagram.com/sworkitapps/'],
#    'status': 'Funded'}],
#  'Episode 19': [{'company': {'link': 'https://www.instafire.com/',
#     'title': 'Insta Fire'},
#    'investors': 'Mark Cuban, Lori Greiner',
#    'kitna': '$300K for 30%',
#    'location': 'Riverdale, UT',
#    'product': 'Fire Starter',
#    'social': ['https://www.facebook.com/InstaFire',
#     'https://twitter.com/instafire'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://custardstand.com/', 'title': 'Custard Stand'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Webster Springs, West Virginia',
#    'product': 'America’s Tastiest Chili',
#    'social': ['https://www.facebook.com/CustardStand/',
#     'https://twitter.com/custardstand',
#     'https://www.instagram.com/custardstand/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://ragstoraches.com/', 'title': 'Rags to Raches'},
#    'investors': 'Robert Herjavec',
#    'kitna': '$200K for 15%',
#    'location': 'Alpine, UT',
#    'product': 'Original Romper',
#    'social': ['https://www.facebook.com/RAGS-To-Raches-640351169384986/',
#     'https://twitter.com/RAGSTORACHES',
#     'https://www.instagram.com/rags_to_raches/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://prxperformance.com/',
#     'title': 'PRX Performance'},
#    'investors': 'Kevin O’ Leary',
#    'kitna': '$80K for 20%',
#    'location': 'Fargo, ND',
#    'product': 'Custom Sports Equipment',
#    'social': ['https://www.facebook.com/PRxPerformance/',
#     'https://twitter.com/prxperformance',
#     'https://www.instagram.com/prxperformance/'],
#    'status': 'Funded'}],
#  'Episode 2': [{'company': {'link': 'https://splikity.com/',
#     'title': 'Splikity'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Paradise Valley, AZ',
#    'product': '\nSecure Password Solution\n',
#    'social': ['https://www.facebook.com/splikity?fref=ts',
#     'https://twitter.com/splikity'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://www.odanghummus.com/',
#     'title': 'O Dang Hummus'},
#    'investors': 'Robert Herjavec and Lori Greiner',
#    'kitna': '$50K for 20%',
#    'location': '\nOrlando, FL\n',
#    'product': 'Hummus',
#    'social': ['https://www.facebook.com/ODangHummus',
#     'https://twitter.com/odanghummus',
#     'https://instagram.com/odanghummus/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.loliware.com/', 'title': 'Loliware'},
#    'investors': '\nMark Cuban and Barbara Corcoran\n',
#    'kitna': '$600K for 25%',
#    'location': '\nNew York, NY\n',
#    'product': 'Edible Cups',
#    'social': ['https://www.facebook.com/loliware-1613039715645348/timeline/',
#     'https://twitter.com/LOLIWARE',
#     'https://instagram.com/loliware/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://mblashes.com/',
#     'title': 'Mikki Bey Eyelash Extensions'},
#    'investors': '',
#    'kitna': '',
#    'location': '\nCulver City, CA\n',
#    'product': '\nEyelash Extensions\n',
#    'social': ['https://www.facebook.com/MikkiBeyEyelashExtensions',
#     'https://twitter.com/MikkiBey',
#     'https://instagram.com/mb_lashes/'],
#    'status': 'Not Funded'}],
#  'Episode 20': [{'company': {'link': 'http://www.glacecryotherapy.com/',
#     'title': 'Glace Cyrotherapy'},
#    'investors': 'Barbara Corcoran',
#    'kitna': '$100K for 30%',
#    'location': 'Carmel, CA',
#    'product': 'Advanced Ice Therapy',
#    'social': ['https://www.facebook.com/glacecryotherapy',
#     'https://twitter.com/glacecryo',
#     'https://www.instagram.com/glacecryotherapy/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://linkalock.com/', 'title': 'Linka'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Oakland, CA',
#    'product': 'Smart Bike Lock',
#    'social': ['https://www.facebook.com/linkabikelock',
#     'https://twitter.com/Velasso4bikes',
#     'https://www.instagram.com/linkabikelocks/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://teaspressa.com/', 'title': 'Teaspressa'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Phoenix, AZ',
#    'product': 'Premium Tea Shots',
#    'social': ['https://www.facebook.com/teaspressa',
#     'https://twitter.com/teaspressa',
#     'https://instagram.com/teaspressa'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://getbetterback.com/', 'title': 'Better Back'},
#    'investors': 'Lori Greiner',
#    'kitna': '$750K for 8%',
#    'location': 'San Francisco, CA',
#    'product': 'Coffee Inspired Tea',
#    'social': ['https://www.facebook.com/teaspressa',
#     'https://twitter.com/getBetterBack',
#     'https://www.instagram.com/getbetterback/'],
#    'status': 'Funded'}],
#  'Episode 21': [{'company': {'link': 'http://illumibowl.com/',
#     'title': 'Illumi Bowl'},
#    'investors': 'Kevin O’ Leary',
#    'kitna': '$100K for 25%',
#    'location': 'Provo, UT',
#    'product': 'Toilet Night Light',
#    'social': ['https://www.facebook.com/illumibowl',
#     'https://twitter.com/illumibowl',
#     'https://instagram.com/illumibowl'],
#    'status': 'Funded'},
#   {'company': {'link': 'https://www.belovedshirts.com/',
#     'title': 'Beloved Shirts'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Provo, UT',
#    'product': 'Creative T-Shirts',
#    'social': ['https://www.facebook.com/BelovedShirts',
#     'https://twitter.com/BelovedShirts',
#     'https://www.instagram.com/belovedshirts/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'https://www.mobcraftbeer.com/',
#     'title': 'Mobcraft Beer'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Madison, WI',
#    'product': 'Craft Brewery',
#    'social': ['https://www.facebook.com/MobCraftBeer',
#     'https://twitter.com/MobCraftBeer',
#     'https://www.instagram.com/mobcraftbeer/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'https://www.innovationpet.com/',
#     'title': 'Innovation Pet'},
#    'investors': 'Daymond John',
#    'kitna': '$250K for 12.5%',
#    'location': 'Orange County, CA',
#    'product': 'Modern Pet Toys',
#    'social': ['https://www.facebook.com/InnovationPet/',
#     'https://twitter.com/innovationpet',
#     'https://www.instagram.com/innovationpet/'],
#    'status': 'Funded'}],
#  'Episode 22': [{'company': {'link': 'http://beerblizzard.com/',
#     'title': 'Beer Blizzard'},
#    'investors': 'Mark Cuban',
#    'kitna': '$100K for 25%',
#    'location': 'Pittsburg, PA',
#    'product': 'Plastic Ice Cube',
#    'social': ['https://www.facebook.com/pages/The-Beer-Blizzard/1426023760984426?fref=ts',
#     'https://twitter.com/beerblizzard',
#     'https://www.instagram.com/beerblizzard/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.thegoodpromise.com/',
#     'title': 'Good Promise'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Austin, TX',
#    'product': 'Nutritional Products',
#    'social': ['https://www.facebook.com/animeals4kids',
#     'https://www.instagram.com/thegoodpromise/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://vengolabs.com/', 'title': 'Vengo'},
#    'investors': 'Lori Greiner and Kevin O’ Leary',
#    'kitna': '$2M for 3%',
#    'location': 'Long Island City, NY',
#    'product': 'High-Tec Vending Machine',
#    'social': ['https://www.facebook.com/VengoLabsNY',
#     'https://twitter.com/VengoLabs',
#     'https://www.instagram.com/vengolabs/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.wondercide.com/', 'title': 'Wondercide'},
#    'investors': 'Lori Greiner',
#    'kitna': '$500K for 3%',
#    'location': 'Austin, TX',
#    'product': 'All-Natural Pet Care',
#    'social': ['https://www.facebook.com/wondercide',
#     'https://twitter.com/Wondercide',
#     'https://www.instagram.com/wondercide/',
#     'https://www.youtube.com/user/Wondercide'],
#    'status': 'Funded'}],
#  'Episode 23': [{'company': {'link': 'http://www.thenophone.com/',
#     'title': 'NoPhone'},
#    'investors': '',
#    'kitna': '',
#    'location': 'New York, NY',
#    'product': 'Fake Phone',
#    'social': ['https://www.facebook.com/thenophone/',
#     'https://twitter.com/TheNoPhone',
#     'https://www.instagram.com/TheNoPhone/',
#     'https://www.youtube.com/c/NoPhone'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://pridebites.com/', 'title': 'PrideBites'},
#    'investors': 'Lori Greiner and Robert Herjavec',
#    'kitna': '$300K for 20%',
#    'location': 'Austin, TX',
#    'product': 'Personalized Pet Products',
#    'social': ['https://www.facebook.com/PrideBites/',
#     'https://twitter.com/pridebites',
#     'http://www.instagram.com/pridebites',
#     'https://www.youtube.com/user/pridebites1'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://mytrobo.com/', 'title': 'Trobo'},
#    'investors': 'Robert Herjavec',
#    'kitna': '$166K for 33%',
#    'location': 'Orlando, FL',
#    'product': 'Educational Robot',
#    'social': ['https://www.facebook.com/mytrobo',
#     'https://twitter.com/mytrobo',
#     'https://www.instagram.com/mytrobo/',
#     'https://www.youtube.com/user/herecomestrobo'],
#    'status': 'Funded'},
#   {'company': {'link': 'https://www.coolbox.io/', 'title': 'Coolbox'},
#    'investors': 'Lori Greiner',
#    'kitna': '$500K for 15%',
#    'location': 'Los Angeles, CA',
#    'product': 'Smart Toolbox',
#    'social': ['https://www.facebook.com/theofficialcoolbox',
#     'https://twitter.com/officialcoolbox',
#     'https://www.instagram.com/officialcoolbox/'],
#    'status': 'Funded'}],
#  'Episode 24': [{'company': {'link': 'http://www.picjoyapp.com/',
#     'title': 'Picjoy'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Salt Lake City, UT',
#    'product': 'Photo Organization App',
#    'social': ['https://www.facebook.com/picjoy',
#     'https://twitter.com/picjoyapp',
#     'https://www.instagram.com/picjoyapp/'],
#    'status': ''},
#   {'company': {'link': 'http://www.wearefrends.com/', 'title': 'Frends'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Encinitas, CA',
#    'product': 'Fashionable Tech Accessories',
#    'social': ['https://www.facebook.com/noIinFRENDS/',
#     'https://twitter.com/wearefrends',
#     'https://www.instagram.com/frends/'],
#    'status': ''},
#   {'company': {'link': 'http://www.slydehandboards.com/', 'title': 'Slyde'},
#    'investors': '',
#    'kitna': '',
#    'location': 'San Clemente, CA',
#    'product': 'Premier Handboards',
#    'social': ['https://www.facebook.com/slydehandboards',
#     'https://twitter.com/slydehandboards',
#     'https://www.instagram.com/slydehandboards/'],
#    'status': ''},
#   {'company': {'link': 'https://www.petnostics.com/', 'title': 'Petnostics'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Los Angeles, CA',
#    'product': 'Pet Health App',
#    'social': ['https://www.facebook.com/Petnostics',
#     'https://twitter.com/petnostics',
#     'https://www.instagram.com/petnostics/'],
#    'status': ''}],
#  'Episode 3': [{'company': {'link': 'http://valparkmobile.com/',
#     'title': 'Valpark Mobile'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Washington, DC',
#    'product': 'Valet App',
#    'social': ['https://www.facebook.com/ValParkMobile',
#     'https://twitter.com/ValParkMobile',
#     'https://instagram.com/valparkmobile/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://www.footcardigan.com/',
#     'title': 'Foot Cardigan'},
#    'investors': '\nMark Cuban and Troy Carter\n',
#    'kitna': '\n$250K for 20%\n',
#    'location': 'Dallas, TX',
#    'product': 'Subscription Socks',
#    'social': ['https://www.facebook.com/footcardigan?fref=ts',
#     'https://twitter.com/FootCardigan',
#     'https://instagram.com/FootCardigan'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.woodenbowties.com/',
#     'title': 'Two Guys Bowtie'},
#    'investors': '\nDaymond John and Troy Carter\n',
#    'kitna': '\n$150K for 17.5% with 10% Royalty\n',
#    'location': 'Tulsa, OK',
#    'product': 'Wooden Bowties',
#    'social': ['https://www.facebook.com/TwoGuysBowTies',
#     'https://twitter.com/TwoGuysBowTies',
#     'https://instagram.com/TwoGuysBowTies'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.nerdwax.com/', 'title': 'Nerdwax'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Nashville, TN',
#    'product': 'Glasses Wax',
#    'social': ['https://www.facebook.com/nerdwax',
#     'https://twitter.com/nerdwax',
#     'https://instagram.com/nerdwax'],
#    'status': 'Not Funded'}],
#  'Episode 4': [{'company': {'link': 'http://www.ezpeez.com/',
#     'title': 'EZ Pee Z'},
#    'investors': '',
#    'kitna': '',
#    'location': '',
#    'product': 'Toilet Training Device',
#    'social': ['https://www.facebook.com/EZPeeZ/',
#     'https://twitter.com/ezpeezpotty',
#     'https://www.youtube.com/channel/UCFUE8Z4zLIqrBcmhdfx0plg'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://www.dudeproducts.com/', 'title': 'Dude Wipes'},
#    'investors': 'Mark Cuban',
#    'kitna': '$300K for 25%',
#    'location': 'Chicago, IL',
#    'product': 'Premium Wipes for Men',
#    'social': ['https://www.facebook.com/DudeProducts/',
#     'https://twitter.com/dudeproducts',
#     'https://instagram.com/dudewipes/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.milkandbrookies.com/',
#     'title': 'Milk and Brookies'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Los Angeles, CA',
#    'product': 'Specialty Desserts',
#    'social': ['https://www.facebook.com/profile.php?id=100008839305387',
#     'https://twitter.com/MilkNBrookies',
#     'https://instagram.com/milk_and_brookies/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://www.table87coalovenpizza.com/',
#     'title': 'Table 87 Pizza'},
#    'investors': 'Lori Greiner',
#    'kitna': '$250K for 19%',
#    'location': 'Brooklyn, NY',
#    'product': 'Coal Oven Pizza',
#    'social': ['https://www.facebook.com/Table-87-Coal-Oven-Pizza-Gowanus-Home-Of-The-Coal-Oven-Slice-746076208801144/?ref=br_tf'],
#    'status': 'Funded'}],
#  'Episode 5': [{'company': {'link': 'http://www.threejerksjerky.com/',
#     'title': 'Three Jerks Jerky'},
#    'investors': 'Daymond John',
#    'kitna': '$100K for 15%',
#    'location': 'Los Angeles, CA',
#    'product': 'Beef Jerky',
#    'social': ['https://www.facebook.com/ThreeJerksJerky?fref=ts',
#     'https://twitter.com/ThreeJerksJerky',
#     'https://instagram.com/ThreeJerksJerky'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.xcraft.io/', 'title': 'X-Craft'},
#    'investors': 'Daymond John, Robert Herjavec, Lori Greiner, Mark Cuban, Barbara Corcoran',
#    'kitna': '$1.5Mfor25%',
#    'location': 'Sandpoint, ID',
#    'product': 'Drone',
#    'social': ['https://twitter.com/xplusonedrone',
#     'https://www.youtube.com/channel/UCqhTQRjybaIGBuj96kTHH-A'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.switch-witch.com/',
#     'title': 'Switch Witch'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Salem, MA',
#    'product': 'New Halloween Tradition',
#    'social': ['https://www.facebook.com/TheOriginalSwitchWitch',
#     'https://twitter.com/YourSwitchWitch',
#     'https://instagram.com/switch_witch/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'https://www.theskinnymirrors.com/',
#     'title': 'Skinny Mirror'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Sand City, CA',
#    'product': 'Slimming Reflection Mirror',
#    'social': ['https://www.facebook.com/TheSkinnyMirror',
#     'https://twitter.com/TheSkinnyMirror',
#     'https://instagram.com/TheSkinnyMirror/'],
#    'status': 'Not Funded'}],
#  'Episode 6': [{'company': {'link': 'http://www.drinkhotshot.com/',
#     'title': 'HotShot'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Hicksville, NY',
#    'product': 'Coffee',
#    'social': ['https://www.facebook.com/Hotshot-72412905711/',
#     'https://twitter.com/hotshotdrinks',
#     'https://www.instagram.com/hotshotcoffee/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://www.windcatchergear.com/',
#     'title': 'Windcatcher'},
#    'investors': 'Lori Greiner',
#    'kitna': '$200K for 5%',
#    'location': 'Portland,OR',
#    'product': 'Quickstream Inflation',
#    'social': ['https://www.facebook.com/windcatchergear',
#     'https://twitter.com/WindcatcherGear',
#     'https://www.instagram.com/windcatchergear/'],
#    'status': 'Funded'},
#   {'company': {'link': 'https://rentlikeachampion.com/',
#     'title': 'Rent Like A Champion'},
#    'investors': 'Mark Cuban and Chris Sacca',
#    'kitna': '$200Kfor 10%',
#    'location': 'Chicago, IL',
#    'product': 'Home Rentals',
#    'social': ['https://www.facebook.com/RentLikeAChampion/?fref=ts',
#     'https://twitter.com/RentLikeAChamp',
#     'https://www.instagram.com/rentlikeachampion/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.stemcenterusa.com/',
#     'title': 'Stem Center'},
#    'investors': 'Lori Greiner',
#    'kitna': '$200Kfor 20%',
#    'location': 'Claremont, CA',
#    'product': 'Science Education',
#    'social': ['https://www.facebook.com/STEMCenterUSA',
#     'https://twitter.com/STEMCenterUSA',
#     'https://www.instagram.com/stemcenterusa/'],
#    'status': 'Funded'}],
#  'Episode 7': [{'company': {'link': 'http://simplyfitboard.com/',
#     'title': 'Simply Fit Board'},
#    'investors': 'Lori Greiner',
#    'kitna': '$125K for 18%',
#    'location': 'Greeley, CO',
#    'product': 'Fitness Board',
#    'social': ['https://www.facebook.com/simplyfitboard/?fref=ts',
#     'https://twitter.com/simplyfitboard',
#     'https://instagram.com/simplyfitboard/'],
#    'status': 'Funded'},
#   {'company': {'link': 'https://www.thecleancube.com/',
#     'title': 'The Clean Cube'},
#    'investors': '',
#    'kitna': '',
#    'location': 'Brooklyn, NY',
#    'product': 'Inventive Dry Cleaning',
#    'social': ['https://www.facebook.com/TheCleanCube',
#     'https://twitter.com/TheCleanCube',
#     'https://instagram.com/thecleancube/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'https://www.saavynaturals.com/',
#     'title': 'Saavy Natural'},
#    'investors': 'Barbara Corcoran',
#    'kitna': '$200K for 40%',
#    'location': 'Chatsworth, CA',
#    'product': 'Artisan Body Care',
#    'social': ['https://www.facebook.com/saavynaturals',
#     'https://twitter.com/saavynaturals',
#     'https://instagram.com/saavynaturals/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://winkfrozendesserts.com/',
#     'title': 'Wink Frozen Desserts'},
#    'investors': '',
#    'kitna': '',
#    'location': 'New York, NY',
#    'product': 'Healthy Desserts',
#    'social': ['https://www.facebook.com/winkfrozendesserts',
#     'https://twitter.com/winkdesserts',
#     'https://instagram.com/winkdesserts/'],
#    'status': 'Not Funded'}],
#  'Episode 8': [{'company': {'link': 'https://www.polarprofilters.com/',
#     'title': 'Polar Pro'},
#    'investors': 'Robert Herjavec and Mark Cuban',
#    'kitna': '$1M for 20%',
#    'location': 'Santa Barbara, CA',
#    'product': 'GoPro Accessories',
#    'social': ['https://www.facebook.com/polarpro/',
#     'https://twitter.com/gopolarpro'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://afresheet.com/', 'title': 'AFreSHeet'},
#    'investors': '',
#    'kitna': '',
#    'location': 'New York, NY',
#    'product': 'Disposable Sheets',
#    'social': ['https://www.facebook.com/AfreSHeet/',
#     'https://twitter.com/Afresheet',
#     'https://www.instagram.com/afresheet/'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'https://www.gripclean.com/', 'title': 'Grip Clean'},
#    'investors': 'Lori Greiner',
#    'kitna': '$85K for 35%',
#    'location': 'Murrieta, CA',
#    'product': 'All Natural Industrial Hand Soap',
#    'social': ['https://www.facebook.com/gripclean/',
#     'https://twitter.com/gripclean',
#     'https://www.instagram.com/gripclean/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://unshrinkit.com/product/',
#     'title': 'UnShrinkIt'},
#    'investors': 'Mark Cuban',
#    'kitna': '$150K for 15%',
#    'location': 'Boston, MA',
#    'product': 'Helps Unshrink Wool',
#    'social': ['https://www.facebook.com/unshrinkit/?fref=ts',
#     'https://twitter.com/unshrinkit',
#     'https://www.instagram.com/unshrinkit/'],
#    'status': 'Funded'}],
#  'Episode 9': [{'company': {'link': 'http://umano.com/', 'title': 'Umano'},
#    'investors': 'Lori Greiner and Mark Cuban',
#    'kitna': '$150K for 20%',
#    'location': 'Athens, GA',
#    'product': 'Clothing Empowering Creativity',
#    'social': ['https://www.facebook.com/umanoClothing/',
#     'https://twitter.com/umanoclothing',
#     'https://www.instagram.com/umanoclothing/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.brazibites.com/', 'title': 'Brazi Bites'},
#    'investors': 'Lori Greiner',
#    'kitna': '$299K for 16.5%',
#    'location': 'Portland, OR',
#    'product': 'Healthy Cheese Bread',
#    'social': ['https://www.facebook.com/BraziBites/?fref=ts',
#     'https://twitter.com/BraziBites',
#     'https://www.instagram.com/brazi_bites/'],
#    'status': 'Funded'},
#   {'company': {'link': 'http://www.nationalbubblesoccer.com/',
#     'title': 'Bubble Soccer'},
#    'investors': '',
#    'kitna': '',
#    'location': '',
#    'product': 'Inventive Soccer Game',
#    'social': ['https://www.facebook.com/nationalbubblesoccer/?fref=ts',
#     'https://twitter.com/USBubbleSoccer'],
#    'status': 'Not Funded'},
#   {'company': {'link': 'http://www.socktabs.com/', 'title': 'SockTabs'},
#    'investors': 'Daymond John',
#    'kitna': '$50K for 30%',
#    'location': 'Rockford, IL',
#    'product': 'Sock Pairing System',
#    'social': ['https://www.facebook.com/socktabs/',
#     'https://twitter.com/sockTABS',
#     'https://www.instagram.com/socktabs/'],
#    'status': 'Funded'}]}

# %%
result = db.show.insert_one("season7.json")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-920baaf9b52b> in <module>()
# ----> 1 result = db.show.insert_one("season7.json")
#
# /usr/local/lib/python3.6/dist-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     673         .. versionadded:: 3.0
#     674         """
# --> 675         common.validate_is_document_type("document", document)
#     676         if not (isinstance(document, RawBSONDocument) or "_id" in document):
#     677             document["_id"] = ObjectId()
#
# /usr/local/lib/python3.6/dist-packages/pymongo/common.py in validate_is_document_type(option, value)
#     432                         "bson.raw_bson.RawBSONDocument, or "
#     433                         "a type that inherits from "
# --> 434                         "collections.MutableMapping" % (option,))
#     435
#     436
#
# TypeError: document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping

# %%
query = db.show.find(
        {
             "Episode 1.status":"Funded"
        },
        {

            "_id":0,
            "Episode 1.title": 1,
            "Episode 1.kitna": 1,
            "Episode 1.investors":1,
            "Episode 1.status":1
        }
)
for document in query:
    display(document)
# Out:
# {'Episode 1': [{'investors': 'Lori Greiner and Ashton Kutcher',
#    'kitna': '$200K for 30%',
#    'status': 'Funded'},
#   {'investors': '', 'kitna': '', 'status': 'Not Funded'},
#   {'investors': 'Robert Herjavec and Lori Greiner',
#    'kitna': '\xa0$200K for 25',
#    'status': 'Funded'},
#   {'investors': '', 'kitna': '', 'status': 'Not Funded'}]}
